# %%
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
Independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]

# %%
Dependent=dataset[['charges']]

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
Independent=sc.fit_transform(Independent)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
param_grid={'kernel':['rbf','poly','sigmoid','linear'],'C':[1,10,100,200,500],'gamma':['auto','scale']}
grid=GridSearchCV(SVR(),param_grid,refit=True,verbose=3,n_jobs=-1)
grid.fit(Independent,Dependent)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# C:\Users\nandh\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [1, 10, 100, 200, 500],
#                          'gamma': ['auto', 'scale'],
#                          'kernel': ['rbf', 'poly', 'sigmoid', 'linear']},
#              verbose=3)

# %%
re=grid.cv_results_
y_pred=grid.predict(Independent)
from sklearn.metrics import r2_score
r_score = r2_score(Dependent,y_pred)
r_score
# Out:
# 0.8167194125081503

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.067222      0.001467         0.029971        0.003116       1
# 1        0.053275      0.005157         0.009913        0.002334       1
# 2        0.076402      0.005981         0.013929        0.001977       1
# 3        0.056170      0.003986         0.008008        0.000896       1
# 4        0.062458      0.004644         0.027940        0.001371       1
# 5        0.054451      0.003559         0.008411        0.001114       1
# 6        0.073088      0.003884         0.012608        0.000852       1
# 7        0.051149      0.004710         0.007803        0.000676       1
# 8        0.065537      0.006069         0.027826        0.001805      10
# 9        0.049616      0.001109         0.008011        0.000448      10
# 10       0.077976      0.006658         0.012623        0.001195      10
# 11       0.054453      0.003106         0.007404        0.000375      10
# 12       0.064470      0.005155         0.026938        0.001262      10
# 13       0.051650      0.004412         0.007609        0.000918      10
# 14       0.074927      0.003158         0.011774        0.000622      10
# 15       0.052989      0.003633         0.007435        0.000555      10
# 16       0.066021      0.003635         0.027819        0.003080     100
# 17       0.060447      0.005144         0.008008        0.000447     100
# 18       0.075925      0.003338         0.012741        0.001683     100
# 19       0.060982      0.005929         0.007303        0.001077     100
# 20       0.062551      0.006525         0.029026        0.002610     100
# 21       0.062949      0.004154         0.008511        0.000633     100
# 22       0.076364      0.005684         0.013614        0.001717     100
# 23       0.057350      0.001752         0.008207        0.001602     100
# 24       0.066556      0.002871         0.027325        0.002543     200
# 25       0.065653      0.005585         0.009308        0.001600     200
# 26       0.078280      0.004826         0.011308        0.000401     200
# 27       0.063350      0.005359         0.008413        0.001625     200
# 28       0.070377      0.003755         0.029325        0.002399     200
# 29       0.062868      0.001032         0.009612        0.001855     200
# 30       0.079788      0.003093         0.011712        0.000249     200
# 31       0.062756      0.005188         0.007710        0.000753     200
# 32       0.071263      0.004192         0.026426        0.001534     500
# 33       0.065957      0.002547         0.008308        0.000674     500
# 34       0.087615      0.001786         0.013589        0.001158     500
# 35       0.068808      0.001658         0.008010        0.000447     500
# 36       0.076082      0.005272         0.032030        0.002000     500
# 37       0.070271      0.003898         0.008008        0.001613     500
# 38       0.080829      0.002959         0.010812        0.001837     500
# 39       0.066015      0.006119         0.006502        0.001266     500
#
#    param_gamma param_kernel  \
# 0         auto          rbf
# 1         auto         poly
# 2         auto      sigmoid
# 3         auto       linear
# 4        scale          rbf
# 5        scale         poly
# 6        scale      sigmoid
# 7        scale       linear
# 8         auto          rbf
# 9         auto         poly
# 10        auto      sigmoid
# 11        auto       linear
# 12       scale          rbf
# 13       scale         poly
# 14       scale      sigmoid
# 15       scale       linear
# 16        auto          rbf
# 17        auto         poly
# 18        auto      sigmoid
# 19        auto       linear
# 20       scale          rbf
# 21       scale         poly
# 22       scale      sigmoid
# 23       scale       linear
# 24        auto          rbf
# 25        auto         poly
# 26        auto      sigmoid
# 27        auto       linear
# 28       scale          rbf
# 29       scale         poly
# 30       scale      sigmoid
# 31       scale       linear
# 32        auto          rbf
# 33        auto         poly
# 34        auto      sigmoid
# 35        auto       linear
# 36       scale          rbf
# 37       scale         poly
# 38       scale      sigmoid
# 39       scale       linear
#
#                                                params  split0_test_score  \
# 0          {'C': 1, 'gamma': 'auto', 'kernel': 'rbf'}          -0.108974
# 1         {'C': 1, 'gamma': 'auto', 'kernel': 'poly'}          -0.099561
# 2      {'C': 1, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.100652
# 3       {'C': 1, 'gamma': 'auto', 'kernel': 'linear'}          -0.025629
# 4         {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}          -0.108985
# 5        {'C': 1, 'gamma': 'scale', 'kernel': 'poly'}          -0.099348
# 6     {'C': 1, 'gamma': 'scale', 'kernel': 'sigmoid'}          -0.100605
# 7      {'C': 1, 'gamma': 'scale', 'kernel': 'linear'}          -0.025629
# 8         {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}          -0.050402
# 9        {'C': 10, 'gamma': 'auto', 'kernel': 'poly'}           0.037227
# 10    {'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.029301
# 11     {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}           0.487873
# 12       {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}          -0.050517
# 13      {'C': 10, 'gamma': 'scale', 'kernel': 'poly'}           0.039041
# 14   {'C': 10, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.029716
# 15    {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}           0.487873
# 16       {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}           0.360724
# 17      {'C': 100, 'gamma': 'auto', 'kernel': 'poly'}           0.650669
# 18   {'C': 100, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.531459
# 19    {'C': 100, 'gamma': 'auto', 'kernel': 'linear'}           0.641464
# 20      {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}           0.360068
# 21     {'C': 100, 'gamma': 'scale', 'kernel': 'poly'}           0.654011
# 22  {'C': 100, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.527367
# 23   {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}           0.641464
# 24       {'C': 200, 'gamma': 'auto', 'kernel': 'rbf'}           0.523083
# 25      {'C': 200, 'gamma': 'auto', 'kernel': 'poly'}           0.754840
# 26   {'C': 200, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.547510
# 27    {'C': 200, 'gamma': 'auto', 'kernel': 'linear'}           0.736713
# 28      {'C': 200, 'gamma': 'scale', 'kernel': 'rbf'}           0.522514
# 29     {'C': 200, 'gamma': 'scale', 'kernel': 'poly'}           0.756133
# 30  {'C': 200, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.546951
# 31   {'C': 200, 'gamma': 'scale', 'kernel': 'linear'}           0.736713
# 32       {'C': 500, 'gamma': 'auto', 'kernel': 'rbf'}           0.716958
# 33      {'C': 500, 'gamma': 'auto', 'kernel': 'poly'}           0.830511
# 34   {'C': 500, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.461625
# 35    {'C': 500, 'gamma': 'auto', 'kernel': 'linear'}           0.677474
# 36      {'C': 500, 'gamma': 'scale', 'kernel': 'rbf'}           0.716580
# 37     {'C': 500, 'gamma': 'scale', 'kernel': 'poly'}           0.831637
# 38  {'C': 500, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.460917
# 39   {'C': 500, 'gamma': 'scale', 'kernel': 'linear'}           0.677474
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0           -0.106280          -0.075075          -0.099676
# 1           -0.095837          -0.066222          -0.091226
# 2           -0.094705          -0.066310          -0.091058
# 3           -0.011630           0.007866          -0.014337
# 4           -0.106259          -0.075060          -0.099683
# 5           -0.096181          -0.066486          -0.091099
# 6           -0.094790          -0.066371          -0.091028
# 7           -0.011630           0.007866          -0.014337
# 8           -0.045276          -0.016737          -0.041345
# 9            0.042884           0.065672           0.041406
# 10           0.043379           0.060402           0.040689
# 11           0.472341           0.485102           0.475835
# 12          -0.045096          -0.016601          -0.041415
# 13           0.040111           0.063362           0.042506
# 14           0.042770           0.059852           0.040918
# 15           0.472341           0.485102           0.475835
# 16           0.347206           0.361437           0.343682
# 17           0.616836           0.642137           0.615462
# 18           0.492180           0.518726           0.511646
# 19           0.601994           0.627339           0.628877
# 20           0.348158           0.362312           0.343255
# 21           0.612976           0.636708           0.617573
# 22           0.490754           0.520064           0.511215
# 23           0.601994           0.627339           0.628877
# 24           0.482160           0.499392           0.495700
# 25           0.715738           0.775277           0.730484
# 26           0.488622           0.523426           0.537980
# 27           0.675488           0.738223           0.696547
# 28           0.482991           0.499997           0.495393
# 29           0.715067           0.772251           0.730564
# 30           0.490304           0.524674           0.512802
# 31           0.675488           0.738223           0.696547
# 32           0.663020           0.685311           0.675312
# 33           0.762343           0.841448           0.784791
# 34           0.442366           0.464095           0.444571
# 35           0.626588           0.732421           0.633634
# 36           0.663481           0.685903           0.675065
# 37           0.760866           0.839232           0.785260
# 38           0.444127           0.467961           0.440759
# 39           0.626588           0.732421           0.633634
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0           -0.100778        -0.098157        0.012041               40
# 1           -0.092426        -0.089054        0.011780               35
# 2           -0.093813        -0.089308        0.011917               37
# 3           -0.027381        -0.014222        0.012632               31
# 4           -0.100792        -0.098156        0.012047               39
# 5           -0.092252        -0.089073        0.011666               36
# 6           -0.093774        -0.089314        0.011889               38
# 7           -0.027381        -0.014222        0.012632               31
# 8           -0.048491        -0.040450        0.012248               34
# 9            0.034393         0.044316        0.011093               28
# 10           0.017824         0.038319        0.014285               29
# 11           0.447692         0.473769        0.014239               21
# 12          -0.048600        -0.040446        0.012321               33
# 13           0.036594         0.044323        0.009707               27
# 14           0.018234         0.038298        0.013912               30
# 15           0.447692         0.473769        0.014239               21
# 16           0.333290         0.349268        0.010678               25
# 17           0.606497         0.626320        0.016993               11
# 18           0.486503         0.508103        0.016679               17
# 19           0.596234         0.619182        0.017199               13
# 20           0.332521         0.349263        0.010997               26
# 21           0.608877         0.626029        0.016930               12
# 22           0.485494         0.506979        0.016308               18
# 23           0.596234         0.619182        0.017199               13
# 24           0.486062         0.497279        0.014333               20
# 25           0.720219         0.739312        0.022507                3
# 26           0.490493         0.517606        0.024159               15
# 27           0.724944         0.714383        0.024534                5
# 28           0.485556         0.497290        0.014067               19
# 29           0.721401         0.739083        0.021692                4
# 30           0.479304         0.510807        0.024147               16
# 31           0.724944         0.714383        0.024534                5
# 32           0.671588         0.682438        0.018684                8
# 33           0.783672         0.800553        0.030210                1
# 34           0.387977         0.440127        0.027499               23
# 35           0.696269         0.673277        0.039486                9
# 36           0.671231         0.682452        0.018531                7
# 37           0.784613         0.800322        0.030083                2
# 38           0.384355         0.439624        0.029437               24
# 39           0.696269         0.673277        0.039486                9
