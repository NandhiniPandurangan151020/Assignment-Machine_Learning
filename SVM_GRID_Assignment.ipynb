# %%
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
Independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
Independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
Dependent=dataset[['charges']]
Dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(Independent,Dependent,test_size=0.30,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
param_grid={'kernel':['rbf','poly','sigmoid','linear'],'C':[1,10,100,200,500],'gamma':['auto','scale']}
grid=GridSearchCV(SVR(),param_grid,refit=True,verbose=3,n_jobs=-1)
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# C:\Users\nandh\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [1, 10, 100, 200, 500],
#                          'gamma': ['auto', 'scale'],
#                          'kernel': ['rbf', 'poly', 'sigmoid', 'linear']},
#              verbose=3)

# %%
re=grid.cv_results_
y_pred=grid.predict(x_test)
from sklearn.metrics import r2_score
r_score = r2_score(y_test,y_pred)
r_score
# Out:
# 0.8263683541269009

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.067572      0.006964         0.030688        0.007485       1
# 1        0.057473      0.004698         0.009867        0.004202       1
# 2        0.079813      0.004675         0.012544        0.004214       1
# 3        0.048458      0.003743         0.005071        0.004523       1
# 4        0.060310      0.006443         0.028925        0.002585       1
# 5        0.052082      0.004123         0.010550        0.002917       1
# 6        0.063995      0.003685         0.014585        0.003597       1
# 7        0.051610      0.005289         0.010494        0.003027       1
# 8        0.060767      0.007821         0.031600        0.001005      10
# 9        0.050718      0.004388         0.010302        0.001971      10
# 10       0.070892      0.005748         0.013552        0.002602      10
# 11       0.054691      0.004342         0.009149        0.001921      10
# 12       0.053777      0.004413         0.027060        0.004493      10
# 13       0.049108      0.005671         0.010430        0.003560      10
# 14       0.077619      0.005966         0.012533        0.000634      10
# 15       0.055927      0.005664         0.008038        0.003279      10
# 16       0.060641      0.006749         0.025141        0.004769     100
# 17       0.056171      0.007893         0.006671        0.004304     100
# 18       0.074330      0.004480         0.012139        0.005580     100
# 19       0.063425      0.003335         0.009107        0.002459     100
# 20       0.062443      0.009816         0.030049        0.001062     100
# 21       0.052324      0.001327         0.010413        0.000852     100
# 22       0.070289      0.003956         0.012178        0.003467     100
# 23       0.061928      0.003530         0.011196        0.001751     100
# 24       0.063644      0.002468         0.027766        0.003339     200
# 25       0.064471      0.003256         0.012489        0.004720     200
# 26       0.083123      0.006513         0.013516        0.006288     200
# 27       0.068062      0.004837         0.007292        0.004487     200
# 28       0.067780      0.008980         0.027581        0.004403     200
# 29       0.076286      0.006577         0.005303        0.003789     200
# 30       0.084954      0.005876         0.015477        0.003738     200
# 31       0.068290      0.004623         0.011245        0.002311     200
# 32       0.086335      0.005003         0.027367        0.004591     500
# 33       0.082566      0.010147         0.008694        0.002119     500
# 34       0.086718      0.004546         0.015323        0.004335     500
# 35       0.074460      0.009117         0.010749        0.002285     500
# 36       0.078772      0.005008         0.028811        0.005280     500
# 37       0.083409      0.009627         0.008441        0.005477     500
# 38       0.081665      0.011741         0.016041        0.003871     500
# 39       0.066342      0.003823         0.008334        0.003770     500
#
#    param_gamma param_kernel  \
# 0         auto          rbf
# 1         auto         poly
# 2         auto      sigmoid
# 3         auto       linear
# 4        scale          rbf
# 5        scale         poly
# 6        scale      sigmoid
# 7        scale       linear
# 8         auto          rbf
# 9         auto         poly
# 10        auto      sigmoid
# 11        auto       linear
# 12       scale          rbf
# 13       scale         poly
# 14       scale      sigmoid
# 15       scale       linear
# 16        auto          rbf
# 17        auto         poly
# 18        auto      sigmoid
# 19        auto       linear
# 20       scale          rbf
# 21       scale         poly
# 22       scale      sigmoid
# 23       scale       linear
# 24        auto          rbf
# 25        auto         poly
# 26        auto      sigmoid
# 27        auto       linear
# 28       scale          rbf
# 29       scale         poly
# 30       scale      sigmoid
# 31       scale       linear
# 32        auto          rbf
# 33        auto         poly
# 34        auto      sigmoid
# 35        auto       linear
# 36       scale          rbf
# 37       scale         poly
# 38       scale      sigmoid
# 39       scale       linear
#
#                                                params  split0_test_score  \
# 0          {'C': 1, 'gamma': 'auto', 'kernel': 'rbf'}          -0.037151
# 1         {'C': 1, 'gamma': 'auto', 'kernel': 'poly'}          -0.031767
# 2      {'C': 1, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.032178
# 3       {'C': 1, 'gamma': 'auto', 'kernel': 'linear'}           0.016409
# 4         {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}          -0.037143
# 5        {'C': 1, 'gamma': 'scale', 'kernel': 'poly'}          -0.031902
# 6     {'C': 1, 'gamma': 'scale', 'kernel': 'sigmoid'}          -0.032208
# 7      {'C': 1, 'gamma': 'scale', 'kernel': 'linear'}           0.016409
# 8         {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}           0.004055
# 9        {'C': 10, 'gamma': 'auto', 'kernel': 'poly'}           0.056274
# 10    {'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.049905
# 11     {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}           0.377969
# 12       {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}           0.004126
# 13      {'C': 10, 'gamma': 'scale', 'kernel': 'poly'}           0.054964
# 14   {'C': 10, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.049644
# 15    {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}           0.377969
# 16       {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}           0.300573
# 17      {'C': 100, 'gamma': 'auto', 'kernel': 'poly'}           0.540643
# 18   {'C': 100, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.478364
# 19    {'C': 100, 'gamma': 'auto', 'kernel': 'linear'}           0.584474
# 20      {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}           0.301041
# 21     {'C': 100, 'gamma': 'scale', 'kernel': 'poly'}           0.537117
# 22  {'C': 100, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.478930
# 23   {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}           0.584474
# 24       {'C': 200, 'gamma': 'auto', 'kernel': 'rbf'}           0.452559
# 25      {'C': 200, 'gamma': 'auto', 'kernel': 'poly'}           0.696668
# 26   {'C': 200, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.501321
# 27    {'C': 200, 'gamma': 'auto', 'kernel': 'linear'}           0.595030
# 28      {'C': 200, 'gamma': 'scale', 'kernel': 'rbf'}           0.452989
# 29     {'C': 200, 'gamma': 'scale', 'kernel': 'poly'}           0.694861
# 30  {'C': 200, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.501143
# 31   {'C': 200, 'gamma': 'scale', 'kernel': 'linear'}           0.595030
# 32       {'C': 500, 'gamma': 'auto', 'kernel': 'rbf'}           0.601529
# 33      {'C': 500, 'gamma': 'auto', 'kernel': 'poly'}           0.781613
# 34   {'C': 500, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.434785
# 35    {'C': 500, 'gamma': 'auto', 'kernel': 'linear'}           0.601152
# 36      {'C': 500, 'gamma': 'scale', 'kernel': 'rbf'}           0.601802
# 37     {'C': 500, 'gamma': 'scale', 'kernel': 'poly'}           0.780516
# 38  {'C': 500, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.466661
# 39   {'C': 500, 'gamma': 'scale', 'kernel': 'linear'}           0.601152
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0           -0.032999          -0.143607          -0.134309
# 1           -0.027414          -0.136684          -0.126981
# 2           -0.026344          -0.136597          -0.129521
# 3            0.033832          -0.083831          -0.078347
# 4           -0.033009          -0.143600          -0.134313
# 5           -0.027215          -0.136794          -0.126911
# 6           -0.026296          -0.136623          -0.129505
# 7            0.033832          -0.083831          -0.078347
# 8            0.013366          -0.103821          -0.095119
# 9            0.069532          -0.045601          -0.025079
# 10           0.075905          -0.046585          -0.041004
# 11           0.479601           0.317872           0.337979
# 12           0.013244          -0.103775          -0.095165
# 13           0.071297          -0.046513          -0.024157
# 14           0.076323          -0.046798          -0.040824
# 15           0.479601           0.317872           0.337979
# 16           0.339474           0.173708           0.217991
# 17           0.575051           0.474839           0.535730
# 18           0.561673           0.428331           0.450454
# 19           0.655818           0.553380           0.576939
# 20           0.338741           0.174086           0.217641
# 21           0.579373           0.471840           0.537966
# 22           0.563200           0.427152           0.451250
# 23           0.655818           0.553380           0.576939
# 24           0.497868           0.352177           0.401731
# 25           0.704051           0.644147           0.693071
# 26           0.589314           0.473825           0.484535
# 27           0.688634           0.559858           0.622351
# 28           0.497218           0.352586           0.401416
# 29           0.706119           0.642964           0.694146
# 30           0.589167           0.473766           0.479113
# 31           0.688634           0.559858           0.622351
# 32           0.640750           0.533952           0.571062
# 33           0.780025           0.754530           0.768597
# 34           0.549481           0.435040           0.430290
# 35           0.599729           0.571527           0.542915
# 36           0.640415           0.534267           0.570844
# 37           0.780878           0.753634           0.768982
# 38           0.542011           0.413211           0.459869
# 39           0.599729           0.571527           0.542915
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0           -0.137861        -0.097185        0.050817               39
# 1           -0.132021        -0.090973        0.050232               36
# 2           -0.131760        -0.091280        0.050723               38
# 3           -0.084332        -0.039254        0.052891               31
# 4           -0.137861        -0.097185        0.050815               40
# 5           -0.132027        -0.090970        0.050261               35
# 6           -0.131761        -0.091279        0.050731               37
# 7           -0.084332        -0.039254        0.052891               31
# 8           -0.101604        -0.056625        0.053504               33
# 9           -0.049592         0.001107        0.051309               28
# 10          -0.046507        -0.001657        0.053391               30
# 11           0.324422         0.367569        0.059777               23
# 12          -0.101602        -0.056634        0.053486               34
# 13          -0.049652         0.001188        0.051594               27
# 14          -0.046521        -0.001635        0.053474               29
# 15           0.324422         0.367569        0.059777               23
# 16           0.183375         0.243024        0.065733               25
# 17           0.424640         0.510181        0.053582               13
# 18           0.431701         0.470105        0.049110               18
# 19           0.546881         0.583498        0.038787                7
# 20           0.183403         0.242982        0.065542               26
# 21           0.424478         0.510155        0.054955               14
# 22           0.432199         0.470546        0.049762               17
# 23           0.546881         0.583498        0.038787                7
# 24           0.363539         0.413575        0.054843               21
# 25           0.569084         0.661404        0.050766                4
# 26           0.466915         0.503182        0.044603               15
# 27           0.559135         0.605002        0.048034                5
# 28           0.363565         0.413555        0.054622               22
# 29           0.568962         0.661411        0.051140                3
# 30           0.466853         0.502008        0.045067               16
# 31           0.559135         0.605002        0.048034                5
# 32           0.521847         0.573828        0.043694               12
# 33           0.687317         0.754417        0.034925                1
# 34           0.425720         0.455063        0.047332               20
# 35           0.565263         0.576117        0.022025                9
# 36           0.521863         0.573838        0.043568               11
# 37           0.687296         0.754261        0.034926                2
# 38           0.428703         0.462091        0.044535               19
# 39           0.565263         0.576117        0.022025                9
