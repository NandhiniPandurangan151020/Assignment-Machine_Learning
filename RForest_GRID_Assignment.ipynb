# %%
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
Independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
Independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
Dependent=dataset[['charges']]
Dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(Independent,Dependent,test_size=0.30,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
param_grid={'criterion':['squared_error', 'friedman_mse', 'absolute_error', 'poisson'],'n_estimators':[50,100],'max_features':[None,'sqrt','log2']}
grid=GridSearchCV(RandomForestRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# C:\Users\nandh\anaconda3\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'n_estimators': [50, 100]},
#              verbose=3)

# %%
re=grid.cv_results_
y_pred=grid.predict(x_test)
from sklearn.metrics import r2_score
r_score = r2_score(y_test,y_pred)
r_score
# Out:
# 0.8694727405067766

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.289066      0.014141         0.008412        0.004204
# 1        0.569771      0.019257         0.016789        0.005483
# 2        0.234181      0.010038         0.013853        0.004962
# 3        0.479526      0.012995         0.013541        0.006269
# 4        0.268299      0.014057         0.009651        0.007542
# 5        0.408254      0.016900         0.017773        0.007263
# 6        0.286051      0.014306         0.004841        0.004063
# 7        0.542353      0.013795         0.018789        0.002373
# 8        0.220725      0.012107         0.009614        0.003470
# 9        0.428763      0.013637         0.015842        0.004278
# 10       0.217356      0.018545         0.009523        0.005587
# 11       0.404708      0.020814         0.015604        0.003557
# 12       1.099231      0.026801         0.011284        0.008580
# 13       8.325745      1.052397         0.082831        0.057209
# 14       1.701931      0.918301         0.038400        0.037094
# 15       7.825227      0.418798         0.077297        0.044933
# 16       3.593780      0.372412         0.033493        0.032374
# 17       7.444370      0.866304         0.038046        0.052998
# 18       1.441533      0.291059         0.119050        0.106619
# 19       3.313195      0.538689         0.024146        0.014159
# 20       1.475978      0.159395         0.048647        0.041909
# 21       2.519282      0.420876         0.103272        0.096855
# 22       1.169141      0.258474         0.016242        0.010207
# 23       1.518411      0.173120         0.037852        0.031386
#
#    param_criterion param_max_features param_n_estimators  \
# 0    squared_error               None                 50
# 1    squared_error               None                100
# 2    squared_error               sqrt                 50
# 3    squared_error               sqrt                100
# 4    squared_error               log2                 50
# 5    squared_error               log2                100
# 6     friedman_mse               None                 50
# 7     friedman_mse               None                100
# 8     friedman_mse               sqrt                 50
# 9     friedman_mse               sqrt                100
# 10    friedman_mse               log2                 50
# 11    friedman_mse               log2                100
# 12  absolute_error               None                 50
# 13  absolute_error               None                100
# 14  absolute_error               sqrt                 50
# 15  absolute_error               sqrt                100
# 16  absolute_error               log2                 50
# 17  absolute_error               log2                100
# 18         poisson               None                 50
# 19         poisson               None                100
# 20         poisson               sqrt                 50
# 21         poisson               sqrt                100
# 22         poisson               log2                 50
# 23         poisson               log2                100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.866857
# 1   {'criterion': 'squared_error', 'max_features':...           0.858051
# 2   {'criterion': 'squared_error', 'max_features':...           0.864700
# 3   {'criterion': 'squared_error', 'max_features':...           0.869334
# 4   {'criterion': 'squared_error', 'max_features':...           0.862227
# 5   {'criterion': 'squared_error', 'max_features':...           0.864905
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.865221
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.861202
# 8   {'criterion': 'friedman_mse', 'max_features': ...           0.858893
# 9   {'criterion': 'friedman_mse', 'max_features': ...           0.861196
# 10  {'criterion': 'friedman_mse', 'max_features': ...           0.862233
# 11  {'criterion': 'friedman_mse', 'max_features': ...           0.862555
# 12  {'criterion': 'absolute_error', 'max_features'...           0.844583
# 13  {'criterion': 'absolute_error', 'max_features'...           0.849202
# 14  {'criterion': 'absolute_error', 'max_features'...           0.853877
# 15  {'criterion': 'absolute_error', 'max_features'...           0.866925
# 16  {'criterion': 'absolute_error', 'max_features'...           0.862926
# 17  {'criterion': 'absolute_error', 'max_features'...           0.851782
# 18  {'criterion': 'poisson', 'max_features': None,...           0.861782
# 19  {'criterion': 'poisson', 'max_features': None,...           0.864473
# 20  {'criterion': 'poisson', 'max_features': 'sqrt...           0.862102
# 21  {'criterion': 'poisson', 'max_features': 'sqrt...           0.862850
# 22  {'criterion': 'poisson', 'max_features': 'log2...           0.869116
# 23  {'criterion': 'poisson', 'max_features': 'log2...           0.861134
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.772472           0.811594           0.795244
# 1            0.766987           0.820030           0.796269
# 2            0.793636           0.803361           0.824903
# 3            0.799051           0.814505           0.824168
# 4            0.796694           0.807173           0.829547
# 5            0.790550           0.808285           0.826375
# 6            0.761022           0.808321           0.808598
# 7            0.768008           0.812843           0.797080
# 8            0.788487           0.808484           0.829356
# 9            0.788288           0.808447           0.829457
# 10           0.784757           0.808421           0.816047
# 11           0.788767           0.806847           0.825644
# 12           0.777535           0.797308           0.788578
# 13           0.772312           0.798314           0.793849
# 14           0.791241           0.804238           0.827040
# 15           0.792029           0.807491           0.827295
# 16           0.785541           0.805205           0.823202
# 17           0.799840           0.804894           0.824622
# 18           0.770850           0.812544           0.800479
# 19           0.768575           0.814020           0.807861
# 20           0.782267           0.813829           0.819632
# 21           0.783703           0.809613           0.830189
# 22           0.787223           0.809991           0.826882
# 23           0.792084           0.811028           0.827888
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.765004         0.802234        0.036289               19
# 1            0.773056         0.802879        0.033345               18
# 2            0.771051         0.811530        0.031722                6
# 3            0.769167         0.815245        0.032836                1
# 4            0.764238         0.811976        0.032770                5
# 5            0.773148         0.812653        0.031581                3
# 6            0.767228         0.802078        0.037333               21
# 7            0.771603         0.802147        0.033841               20
# 8            0.767904         0.810625        0.031624                9
# 9            0.768107         0.811099        0.032319                8
# 10           0.768775         0.808047        0.031890               16
# 11           0.765775         0.809918        0.032934               12
# 12           0.765795         0.794760        0.027065               24
# 13           0.764485         0.795632        0.029645               23
# 14           0.771679         0.809615        0.028525               13
# 15           0.771524         0.813053        0.032566                2
# 16           0.767026         0.808780        0.032972               14
# 17           0.771432         0.810514        0.026740               11
# 18           0.763913         0.801914        0.034952               22
# 19           0.770348         0.805055        0.035083               17
# 20           0.764918         0.808550        0.033505               15
# 21           0.766576         0.810586        0.033989               10
# 22           0.764180         0.811479        0.035741                7
# 23           0.770008         0.812428        0.031069                4
