# %%
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
Independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
Independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
Dependent=dataset[['charges']]
Dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(Independent,Dependent,test_size=0.30,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid={'criterion':['squared_error', 'friedman_mse', 'absolute_error', 'poisson'],'splitter':['best', 'random'],'max_features':[None,'sqrt','log2']}
grid=GridSearchCV(DecisionTreeRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
re=grid.cv_results_
y_pred=grid.predict(x_test)
from sklearn.metrics import r2_score
r_score = r2_score(y_test,y_pred)
r_score
# Out:
# 0.7117547766144692

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.008895      0.001432         0.005058        0.004135
# 1        0.010329      0.006880         0.006664        0.003521
# 2        0.007480      0.000538         0.002938        0.003128
# 3        0.005769      0.004901         0.002624        0.004756
# 4        0.006391      0.004920         0.001366        0.002346
# 5        0.004421      0.003901         0.005038        0.003148
# 6        0.011130      0.000951         0.000000        0.000000
# 7        0.006690      0.003363         0.002885        0.002535
# 8        0.005467      0.005283         0.002338        0.004677
# 9        0.004345      0.004841         0.002250        0.003308
# 10       0.004493      0.001089         0.003373        0.002819
# 11       0.002600      0.002926         0.002098        0.004196
# 12       0.038742      0.004117         0.000000        0.000000
# 13       0.032188      0.006306         0.000000        0.000000
# 14       0.022261      0.004411         0.003233        0.003960
# 15       0.019113      0.003060         0.002322        0.003120
# 16       0.022885      0.003857         0.000669        0.001338
# 17       0.020632      0.001662         0.002695        0.004053
# 18       0.010319      0.001002         0.000604        0.001208
# 19       0.008278      0.002617         0.000167        0.000333
# 20       0.005032      0.005278         0.002549        0.003878
# 21       0.004552      0.005001         0.004324        0.003664
# 22       0.006874      0.004168         0.001737        0.003474
# 23       0.000034      0.000068         0.003145        0.003887
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               None           best
# 1    squared_error               None         random
# 2    squared_error               sqrt           best
# 3    squared_error               sqrt         random
# 4    squared_error               log2           best
# 5    squared_error               log2         random
# 6     friedman_mse               None           best
# 7     friedman_mse               None         random
# 8     friedman_mse               sqrt           best
# 9     friedman_mse               sqrt         random
# 10    friedman_mse               log2           best
# 11    friedman_mse               log2         random
# 12  absolute_error               None           best
# 13  absolute_error               None         random
# 14  absolute_error               sqrt           best
# 15  absolute_error               sqrt         random
# 16  absolute_error               log2           best
# 17  absolute_error               log2         random
# 18         poisson               None           best
# 19         poisson               None         random
# 20         poisson               sqrt           best
# 21         poisson               sqrt         random
# 22         poisson               log2           best
# 23         poisson               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.725466
# 1   {'criterion': 'squared_error', 'max_features':...           0.746884
# 2   {'criterion': 'squared_error', 'max_features':...           0.618324
# 3   {'criterion': 'squared_error', 'max_features':...           0.726023
# 4   {'criterion': 'squared_error', 'max_features':...           0.524466
# 5   {'criterion': 'squared_error', 'max_features':...           0.611575
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.756350
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.694774
# 8   {'criterion': 'friedman_mse', 'max_features': ...           0.841401
# 9   {'criterion': 'friedman_mse', 'max_features': ...           0.643668
# 10  {'criterion': 'friedman_mse', 'max_features': ...           0.721992
# 11  {'criterion': 'friedman_mse', 'max_features': ...           0.406063
# 12  {'criterion': 'absolute_error', 'max_features'...           0.752990
# 13  {'criterion': 'absolute_error', 'max_features'...           0.704937
# 14  {'criterion': 'absolute_error', 'max_features'...           0.746759
# 15  {'criterion': 'absolute_error', 'max_features'...           0.639840
# 16  {'criterion': 'absolute_error', 'max_features'...           0.674459
# 17  {'criterion': 'absolute_error', 'max_features'...           0.728956
# 18  {'criterion': 'poisson', 'max_features': None,...           0.704497
# 19  {'criterion': 'poisson', 'max_features': None,...           0.727366
# 20  {'criterion': 'poisson', 'max_features': 'sqrt...           0.624826
# 21  {'criterion': 'poisson', 'max_features': 'sqrt...           0.623808
# 22  {'criterion': 'poisson', 'max_features': 'log2...           0.736782
# 23  {'criterion': 'poisson', 'max_features': 'log2...           0.654058
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.542326           0.773314           0.625116
# 1            0.673837           0.652964           0.557588
# 2            0.581885           0.703938           0.692404
# 3            0.529984           0.642971           0.514316
# 4            0.262292           0.658246           0.537328
# 5            0.588903           0.687912           0.590343
# 6            0.593351           0.774661           0.634354
# 7            0.687497           0.648926           0.458723
# 8            0.649701           0.641833           0.608772
# 9            0.546914           0.455566           0.469588
# 10           0.676341           0.496052           0.642495
# 11           0.678565           0.643034           0.484336
# 12           0.598853           0.596405           0.541367
# 13           0.630635           0.726405           0.620948
# 14           0.513469           0.635822           0.495226
# 15           0.568337           0.561097           0.720110
# 16           0.666734           0.709602           0.432968
# 17           0.541182           0.668430           0.358678
# 18           0.596731           0.759353           0.618950
# 19           0.624010           0.582980           0.639219
# 20           0.673307           0.637554           0.547421
# 21           0.701182           0.471729           0.598262
# 22           0.611663           0.789575           0.450666
# 23           0.602291           0.606708           0.640004
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.676612         0.668567        0.080123                4
# 1            0.655093         0.657273        0.060440                6
# 2            0.681256         0.655562        0.047271                7
# 3            0.506257         0.583910        0.086563               19
# 4            0.527505         0.501967        0.129828               24
# 5            0.622311         0.620209        0.036152               15
# 6            0.666720         0.685087        0.069898                1
# 7            0.672596         0.632503        0.088294               11
# 8            0.620408         0.672423        0.085747                3
# 9            0.559332         0.535014        0.068017               23
# 10           0.643768         0.636130        0.075776               10
# 11           0.521530         0.546706        0.100965               22
# 12           0.667652         0.631453        0.072785               12
# 13           0.706341         0.677853        0.043290                2
# 14           0.687855         0.615826        0.097727               16
# 15           0.366365         0.571150        0.117434               20
# 16           0.631031         0.622959        0.098221               14
# 17           0.546263         0.568702        0.127278               21
# 18           0.630761         0.662058        0.060618                5
# 19           0.608953         0.636506        0.049078                9
# 20           0.658411         0.628304        0.043752               13
# 21           0.670859         0.613168        0.079266               18
# 22           0.618717         0.641481        0.117330                8
# 23           0.574534         0.615519        0.028345               17
